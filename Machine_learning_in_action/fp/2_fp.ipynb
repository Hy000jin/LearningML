# %%
import sys
sys.path.insert(0, '../../../../../DATA/ml/machinelearninginaction/Ch12/')

import fpGrowth

# %% [markdown]
# # kosarak.dat

# %%
import pandas as pd

# %%
df = pd.read_csv('../../../../../DATA/ml/machinelearninginaction/Ch12/kosarak.dat', header = None)
df.columns = ['tf']
df.head()
# Out:
#         tf
# 0    1 2 3
# 1        1
# 2  4 5 6 7
# 3      1 8
# 4     9 10

# %%
df['tf'].value_counts()
# Out:
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     
# ...

# %%
parsedDat = [line.split() for line in open('../../../../../DATA/ml/machinelearninginaction/Ch12/kosarak.dat').readlines()]

# %%
print(parsedDat[:10])
# Out:
# [['1', '2', '3'], ['1'], ['4', '5', '6', '7'], ['1', '8'], ['9', '10'], ['11', '6', '12', '13', '14', '15', '16'], ['1', '3', '7'], ['17', '18'], ['11', '6', '19', '20', '21', '22', '23', '24'], ['1', '25', '3']]

# %%
initSet = fpGrowth.createInitSet(parsedDat)

# %%
print(type(initSet))
# Out:
# <class 'dict'>

# %%
myFPtree, myHeaderTab = fpGrowth.createTree(initSet, 100000)

# %%
myFreqList = []

# %%
fpGrowth.mineTree(myFPtree, myHeaderTab, 100000, set([]), myFreqList)
# Out:
# conditional tree for:  {'1'}
#    Null Set   1
#      6   107404
# conditional tree for:  {'11'}
#    Null Set   1
#      6   261773
# conditional tree for:  {'3'}
#    Null Set   1
#      6   186289
#        11   117401
#      11   9718
# conditional tree for:  {'11', '3'}
#    Null Set   1
#      6   117401

# %%
len(myFreqList)
# Out:
# 9

# %%
myFreqList
# Out:
# [{'1'},
#  {'1', '6'},
#  {'11'},
#  {'11', '6'},
#  {'3'},
#  {'11', '3'},
#  {'11', '3', '6'},
#  {'3', '6'},
#  {'6'}]
